# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("D:\programming_advance\data_bot\data\covid_vaccine_statewise.csv")

# %%
df.head(50)
# Out:
#     Updated On  State  Total Doses Administered  Sessions   Sites   \
# 0   16/01/2021  India                   48276.0    3455.0   2957.0
# 1   17/01/2021  India                   58604.0    8532.0   4954.0
# 2   18/01/2021  India                   99449.0   13611.0   6583.0
# 3   19/01/2021  India                  195525.0   17855.0   7951.0
# 4   20/01/2021  India                  251280.0   25472.0  10504.0
# 5   21/01/2021  India                  365965.0   32226.0  12600.0
# 6   22/01/2021  India                  549381.0   36988.0  14115.0
# 7   23/01/2021  India                  759008.0   43076.0  15605.0
# 8   24/01/2021  India                  835058.0   49851.0  18111.0
# 9   25/01/2021  India                 1277104.0   55151.0  19682.0
# 10  26/01/2021  India                 1293784.0   60821.0  21467.0
# 11  27/01/2021  India                 1726490.0   69495.0  23737.0
# 12  28/01/2021  India                 2295491.0   78523.0  25610.0
# ...

# %%
df.dtypes
# Out:
# Updated On                              object
# State                                   object
# Total Doses Administered               float64
# Sessions                               float64
#  Sites                                 float64
# First Dose Administered                float64
# Second Dose Administered               float64
# Male (Doses Administered)              float64
# Female (Doses Administered)            float64
# Transgender (Doses Administered)       float64
#  Covaxin (Doses Administered)          float64
# CoviShield (Doses Administered)        float64
# Sputnik V (Doses Administered)         float64
# AEFI                                   float64
# 18-44 Years (Doses Administered)       float64
# 45-60 Years (Doses Administered)       float64
# 60+ Years (Doses Administered)         float64
# 18-44 Years(Individuals Vaccinated)    float64
# 45-60 Years(Individuals Vaccinated)    float64
# 60+ Years(Individuals Vaccinated)      float64
# ...

# %%
df.shape
# Out:
# (7845, 24)

# %%
df.skew()
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_23040\1665899112.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.skew()
# Total Doses Administered                8.974892
# Sessions                                8.861600
#  Sites                                  6.329796
# First Dose Administered                 8.836730
# Second Dose Administered                9.570291
# Male (Doses Administered)              11.955778
# Female (Doses Administered)            12.040126
# Transgender (Doses Administered)       12.095873
#  Covaxin (Doses Administered)           9.328207
# CoviShield (Doses Administered)         8.906886
# Sputnik V (Doses Administered)          9.110965
# AEFI                                    5.578262
# 18-44 Years (Doses Administered)        5.903469
# ...

# %%
df.loc[0:784,["Total Doses Administered","AEFI"]]
# Out:
#      Total Doses Administered   AEFI
# 0                     48276.0    NaN
# 1                     58604.0    NaN
# 2                     99449.0    NaN
# 3                    195525.0    NaN
# 4                    251280.0    NaN
# ..                        ...    ...
# 780                  395757.0  271.0
# 781                  400648.0  271.0
# 782                  405483.0  271.0
# 783                  410393.0  272.0
# 784                  414648.0  272.0
#
# [785 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# Updated On                                0
# State                                     0
# Total Doses Administered                224
# Sessions                                224
#  Sites                                  224
# First Dose Administered                 224
# Second Dose Administered                224
# Male (Doses Administered)               384
# Female (Doses Administered)             384
# Transgender (Doses Administered)        384
#  Covaxin (Doses Administered)           224
# CoviShield (Doses Administered)         224
# Sputnik V (Doses Administered)         4850
# AEFI                                   2407
# 18-44 Years (Doses Administered)       6143
# 45-60 Years (Doses Administered)       6143
# 60+ Years (Doses Administered)         6143
# 18-44 Years(Individuals Vaccinated)    4112
# 45-60 Years(Individuals Vaccinated)    4111
# 60+ Years(Individuals Vaccinated)      4111
# Male(Individuals Vaccinated)           7685
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (7845, 24)

# %%
df.groupby(['State']).mean()
# Out:
#                                           Total Doses Administered  \
# State
# Andaman and Nicobar Islands                           9.973014e+04
# Andhra Pradesh                                        7.726594e+06
# Arunachal Pradesh                                     2.958121e+05
# Assam                                                 3.477617e+06
# Bihar                                                 8.452881e+06
# Chandigarh                                            2.732856e+05
# Chhattisgarh                                          4.699628e+06
# Dadra and Nagar Haveli and Daman and Diu              1.862901e+05
# Delhi                                                 3.944458e+06
# Goa                                                   4.475220e+05
# Gujarat                                               1.326245e+07
# Haryana                                               4.439099e+06
# Himachal Pradesh                                      1.893848e+06
# ...

# %%
df.corr()
# Out:
#                                      Total Doses Administered  Sessions  \
# Total Doses Administered                             1.000000  0.911988
# Sessions                                             0.911988  1.000000
#  Sites                                               0.671316  0.763954
# First Dose Administered                              0.999592  0.918317
# Second Dose Administered                             0.993599  0.879641
# Male (Doses Administered)                            0.999555  0.918149
# Female (Doses Administered)                          0.999514  0.917061
# Transgender (Doses Administered)                     0.995388  0.907557
#  Covaxin (Doses Administered)                        0.995926  0.900257
# CoviShield (Doses Administered)                      0.999912  0.913249
# Sputnik V (Doses Administered)                       0.821080  0.658084
# AEFI                                                 0.910686  0.893970
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7845 entries, 0 to 7844
# Data columns (total 24 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Updated On                           7845 non-null   object
#  1   State                                7845 non-null   object
#  2   Total Doses Administered             7621 non-null   float64
#  3   Sessions                             7621 non-null   float64
#  4    Sites                               7621 non-null   float64
#  5   First Dose Administered              7621 non-null   float64
#  6   Second Dose Administered             7621 non-null   float64
#  7   Male (Doses Administered)            7461 non-null   float64
#  8   Female (Doses Administered)          7461 non-null   float64
#  9   Transgender (Doses Administered)     7461 non-null   float64
#  10   Covaxin (Doses Administered)        7621 non-null   float64
# ...

# %%
df.count()
# Out:
# Updated On                             7845
# State                                  7845
# Total Doses Administered               7621
# Sessions                               7621
#  Sites                                 7621
# First Dose Administered                7621
# Second Dose Administered               7621
# Male (Doses Administered)              7461
# Female (Doses Administered)            7461
# Transgender (Doses Administered)       7461
#  Covaxin (Doses Administered)          7621
# CoviShield (Doses Administered)        7621
# Sputnik V (Doses Administered)         2995
# AEFI                                   5438
# 18-44 Years (Doses Administered)       1702
# 45-60 Years (Doses Administered)       1702
# 60+ Years (Doses Administered)         1702
# 18-44 Years(Individuals Vaccinated)    3733
# 45-60 Years(Individuals Vaccinated)    3734
# 60+ Years(Individuals Vaccinated)      3734
# Male(Individuals Vaccinated)            160
# ...

# %%
df["State"].unique()
# Out:
# array(['India', 'Andaman and Nicobar Islands', 'Andhra Pradesh',
#        'Arunachal Pradesh', 'Assam', 'Bihar', 'Chandigarh',
#        'Chhattisgarh', 'Dadra and Nagar Haveli and Daman and Diu',
#        'Delhi', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu and Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh',
#        'Lakshadweep', 'Madhya Pradesh', 'Maharashtra', 'Manipur',
#        'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha', 'Puducherry',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
df["18-44 Years"].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\programming_advance\data_bot\venv\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    <a href='file:///d%3A/programming_advance/data_bot/venv/lib/site-packages/pandas/core/indexes/base.py?line=3619'>3620</a> try:
# -> <a href='file:///d%3A/programming_advance/data_bot/venv/lib/site-packages/pandas/core/indexes/base.py?line=3620'>3621</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///d%3A/programming_advance/data_bot/venv/lib/site-packages/pandas/core/indexes/base.py?line=3621'>3622</a> except KeyError as err:
#
# File d:\programming_advance\data_bot\venv\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# ...

# %%
df.nsmallest(200,"Male(Individuals Vaccinated)")
# Out:
#      Updated On  State  Total Doses Administered    Sessions   Sites   \
# 0    16/01/2021  India                   48276.0      3455.0   2957.0
# 1    17/01/2021  India                   58604.0      8532.0   4954.0
# 2    18/01/2021  India                   99449.0     13611.0   6583.0
# 3    19/01/2021  India                  195525.0     17855.0   7951.0
# 4    20/01/2021  India                  251280.0     25472.0  10504.0
# ..          ...    ...                       ...         ...      ...
# 195  30/07/2021  India               456471250.0  20918871.0  45339.0
# 196  31/07/2021  India               463113439.0  22141942.0  47334.0
# 197  01/08/2021  India               467769865.0   9847327.0  20066.0
# 198  02/08/2021  India               473977156.0  22612516.0  47979.0
# 199  03/08/2021  India               480643928.0  23639645.0  47616.0
#
#      First Dose Administered  Second Dose Administered  \
# 0                    48276.0                       0.0
# ...

# %%
df.nlargest(200,"Female(Individuals Vaccinated)")
# Out:
#      Updated On  State  Total Doses Administered    Sessions   Sites   \
# 159  24/06/2021  India               303426850.0  26458510.0  56282.0
# 158  23/06/2021  India               296892521.0  27105115.0  59462.0
# 157  22/06/2021  India               289961746.0  23436266.0  54639.0
# 156  21/06/2021  India               283891764.0  35010311.0  68061.0
# 155  20/06/2021  India               275018693.0  12736409.0  24766.0
# ..          ...    ...                       ...         ...      ...
# 195  30/07/2021  India               456471250.0  20918871.0  45339.0
# 196  31/07/2021  India               463113439.0  22141942.0  47334.0
# 197  01/08/2021  India               467769865.0   9847327.0  20066.0
# 198  02/08/2021  India               473977156.0  22612516.0  47979.0
# 199  03/08/2021  India               480643928.0  23639645.0  47616.0
#
#      First Dose Administered  Second Dose Administered  \
# 159              250656880.0                52769970.0
# ...

# %%
df.isnull().sum()
# Out:
# Updated On                                0
# State                                     0
# Total Doses Administered                224
# Sessions                                224
#  Sites                                  224
# First Dose Administered                 224
# Second Dose Administered                224
# Male (Doses Administered)               384
# Female (Doses Administered)             384
# Transgender (Doses Administered)        384
#  Covaxin (Doses Administered)           224
# CoviShield (Doses Administered)         224
# Sputnik V (Doses Administered)         4850
# AEFI                                   2407
# 18-44 Years (Doses Administered)       6143
# 45-60 Years (Doses Administered)       6143
# 60+ Years (Doses Administered)         6143
# 18-44 Years(Individuals Vaccinated)    4112
# 45-60 Years(Individuals Vaccinated)    4111
# 60+ Years(Individuals Vaccinated)      4111
# Male(Individuals Vaccinated)           7685
# ...

# %%
df
# Out:
#       Updated On        State  Total Doses Administered  Sessions   Sites   \
# 0     16/01/2021        India                   48276.0    3455.0   2957.0
# 1     17/01/2021        India                   58604.0    8532.0   4954.0
# 2     18/01/2021        India                   99449.0   13611.0   6583.0
# 3     19/01/2021        India                  195525.0   17855.0   7951.0
# 4     20/01/2021        India                  251280.0   25472.0  10504.0
# ...          ...          ...                       ...       ...      ...
# 7840  11/08/2021  West Bengal                       NaN       NaN      NaN
# 7841  12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842  13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843  14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844  15/08/2021  West Bengal                       NaN       NaN      NaN
#
#       First Dose Administered  Second Dose Administered  \
# ...

# %%
df.sort_values("Male(Individuals Vaccinated)")
# Out:
#       Updated On        State  Total Doses Administered  Sessions   Sites   \
# 0     16/01/2021        India                   48276.0    3455.0   2957.0
# 1     17/01/2021        India                   58604.0    8532.0   4954.0
# 2     18/01/2021        India                   99449.0   13611.0   6583.0
# 3     19/01/2021        India                  195525.0   17855.0   7951.0
# 4     20/01/2021        India                  251280.0   25472.0  10504.0
# ...          ...          ...                       ...       ...      ...
# 7840  11/08/2021  West Bengal                       NaN       NaN      NaN
# 7841  12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842  13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843  14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844  15/08/2021  West Bengal                       NaN       NaN      NaN
#
#       First Dose Administered  Second Dose Administered  \
# ...

# %%
df
# Out:
#       Updated On        State  Total Doses Administered  Sessions   Sites   \
# 0     16/01/2021        India                   48276.0    3455.0   2957.0
# 1     17/01/2021        India                   58604.0    8532.0   4954.0
# 2     18/01/2021        India                   99449.0   13611.0   6583.0
# 3     19/01/2021        India                  195525.0   17855.0   7951.0
# 4     20/01/2021        India                  251280.0   25472.0  10504.0
# ...          ...          ...                       ...       ...      ...
# 7840  11/08/2021  West Bengal                       NaN       NaN      NaN
# 7841  12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842  13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843  14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844  15/08/2021  West Bengal                       NaN       NaN      NaN
#
#       First Dose Administered  Second Dose Administered  \
# ...

# %%
df[['Total Doses Administered','State']].groupby('State').mean()
# Out:
#                                           Total Doses Administered
# State
# Andaman and Nicobar Islands                           9.973014e+04
# Andhra Pradesh                                        7.726594e+06
# Arunachal Pradesh                                     2.958121e+05
# Assam                                                 3.477617e+06
# Bihar                                                 8.452881e+06
# Chandigarh                                            2.732856e+05
# Chhattisgarh                                          4.699628e+06
# Dadra and Nagar Haveli and Daman and Diu              1.862901e+05
# Delhi                                                 3.944458e+06
# Goa                                                   4.475220e+05
# Gujarat                                               1.326245e+07
# Haryana                                               4.439099e+06
# Himachal Pradesh                                      1.893848e+06
# ...

# %%
df[['Total Doses Administered','State']].groupby(['State']).agg(['mean','max'])
# Out:
#                                          Total Doses Administered
#                                                              mean          max
# State
# Andaman and Nicobar Islands                          9.973014e+04     310643.0
# Andhra Pradesh                                       7.726594e+06   23842895.0
# Arunachal Pradesh                                    2.958121e+05     879094.0
# Assam                                                3.477617e+06   12703870.0
# Bihar                                                8.452881e+06   27834939.0
# Chandigarh                                           2.732856e+05     923819.0
# Chhattisgarh                                         4.699628e+06   11769177.0
# Dadra and Nagar Haveli and Daman and Diu             1.862901e+05     665221.0
# Delhi                                                3.944458e+06   10836082.0
# Goa                                                  4.475220e+05    1396911.0
# ...

# %%
df.iloc[15:20,3:7]
# Out:
#     Sessions   Sites   First Dose Administered  Second Dose Administered
# 15   91593.0  27011.0                3127107.0                       0.0
# 16   97432.0  27751.0                3350265.0                       0.0
# 17  106461.0  29522.0                3527971.0                       0.0
# 18  116568.0  31167.0                3825835.0                       0.0
# 19  126714.0  32505.0                4314304.0                       0.0

# %%
df
# Out:
#       Updated On        State  Total Doses Administered  Sessions   Sites   \
# 0     16/01/2021        India                   48276.0    3455.0   2957.0
# 1     17/01/2021        India                   58604.0    8532.0   4954.0
# 2     18/01/2021        India                   99449.0   13611.0   6583.0
# 3     19/01/2021        India                  195525.0   17855.0   7951.0
# 4     20/01/2021        India                  251280.0   25472.0  10504.0
# ...          ...          ...                       ...       ...      ...
# 7840  11/08/2021  West Bengal                       NaN       NaN      NaN
# 7841  12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842  13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843  14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844  15/08/2021  West Bengal                       NaN       NaN      NaN
#
#       First Dose Administered  Second Dose Administered  \
# ...

# %%
df.nlargest(5,'Total Doses Administered')
# Out:
#      Updated On  State  Total Doses Administered    Sessions   Sites   \
# 205  09/08/2021  India               513228400.0  21978176.0  46163.0
# 204  08/08/2021  India               507727903.0  10353120.0  18971.0
# 203  07/08/2021  India               505787038.0  22675183.0  46089.0
# 202  06/08/2021  India               500087070.0  20015484.0  41826.0
# 201  05/08/2021  India               490760938.0  22435536.0  48656.0
#
#      First Dose Administered  Second Dose Administered  \
# 205              400150406.0               113077994.0
# 204              395961470.0               111766433.0
# 203              394599261.0               111187777.0
# 202              390344882.0               109742188.0
# 201              382658786.0               108102152.0
#
#      Male (Doses Administered)  Female (Doses Administered)  \
# 205                270163622.0                  239518609.0
# 204                267236380.0                  236796948.0
# ...

# %%
df.nsmallest(5,'Total Doses Administered')
# Out:
#       Updated On   State  Total Doses Administered  Sessions   Sites   \
# 6361  16/01/2021  Sikkim                       7.0       2.0      2.0
# 6362  17/01/2021  Sikkim                       7.0       2.0      2.0
# 6363  18/01/2021  Sikkim                       7.0       6.0      3.0
# 3817  16/01/2021  Ladakh                       9.0       1.0      1.0
# 3818  17/01/2021  Ladakh                       9.0       2.0      2.0
#
#       First Dose Administered  Second Dose Administered  \
# 6361                      7.0                       0.0
# 6362                      7.0                       0.0
# 6363                      7.0                       0.0
# 3817                      9.0                       0.0
# 3818                      9.0                       0.0
#
#       Male (Doses Administered)  Female (Doses Administered)  \
# 6361                        3.0                          4.0
# 6362                        3.0                          4.0
# ...

# %%
df.sort_values("State").head(10)
# Out:
#      Updated On                        State  Total Doses Administered  \
# 423  15/08/2021  Andaman and Nicobar Islands                       NaN
# 287  01/04/2021  Andaman and Nicobar Islands                   22608.0
# 286  31/03/2021  Andaman and Nicobar Islands                   21938.0
# 285  30/03/2021  Andaman and Nicobar Islands                   21840.0
# 284  29/03/2021  Andaman and Nicobar Islands                   21357.0
# 283  28/03/2021  Andaman and Nicobar Islands                   21358.0
# 282  27/03/2021  Andaman and Nicobar Islands                   21356.0
# 281  26/03/2021  Andaman and Nicobar Islands                   20789.0
# 280  25/03/2021  Andaman and Nicobar Islands                   20318.0
# 279  24/03/2021  Andaman and Nicobar Islands                   19693.0
#
#      Sessions   Sites   First Dose Administered  Second Dose Administered  \
# 423       NaN      NaN                      NaN                       NaN
# ...

# %%
sns.heatmap(df[['Male (Doses Administered)', 'Total Doses Administered']])
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#       Updated On        State  Total Doses Administered  Sessions   Sites   \
# 0     16/01/2021        India                   48276.0    3455.0   2957.0
# 1     17/01/2021        India                   58604.0    8532.0   4954.0
# 2     18/01/2021        India                   99449.0   13611.0   6583.0
# 3     19/01/2021        India                  195525.0   17855.0   7951.0
# 4     20/01/2021        India                  251280.0   25472.0  10504.0
# ...          ...          ...                       ...       ...      ...
# 7840  11/08/2021  West Bengal                       NaN       NaN      NaN
# 7841  12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842  13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843  14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844  15/08/2021  West Bengal                       NaN       NaN      NaN
#
#       First Dose Administered  Second Dose Administered  \
# ...
